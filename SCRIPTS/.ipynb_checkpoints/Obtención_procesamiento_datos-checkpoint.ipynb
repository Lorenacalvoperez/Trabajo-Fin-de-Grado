# %% [markdown]
# # PROCESAMIENTO DE DATOS

# %% [markdown]
# ## Función general para la carga de los datos

# %%
def cargar_datos():
   
    datos = requests.get(DATA_URL).json()  # Datos de casos de Parkinson
    metadata = requests.get(METADATA_URL).json()  # Información adicional (años y países)
    return datos, metadata

# %% [markdown]
# ## Función general para el procesamiento de los datos

# %%
def procesar_datos(data_response, metadata_response):
    # Extraer los valores numéricos (dependiendo de la estructura)
    if "values" in data_response:
        valores = data_response["values"]
    else:
        raise ValueError("No se encontró la clave 'values' en los datos")

    # Extraer la lista de años disponibles (independientemente de la estructura específica)
    if "dimensions" in metadata_response and "years" in metadata_response["dimensions"]:
        años = [item["id"] for item in metadata_response["dimensions"]["years"]["values"]]
    else:
        raise ValueError("No se encontró la clave 'years' en la metadata")

    # Extraer los países o entidades desde la metadata (independientemente de la estructura específica)
    if "dimensions" in metadata_response and "entities" in metadata_response["dimensions"]:
        paises = {item["id"]: item["name"] for item in metadata_response["dimensions"]["entities"]["values"]}
    else:
        raise ValueError("No se encontró la clave 'entities' en la metadata")
    
    return valores, años, paises

# %% [markdown]
# ## Función general para la creación de DF

# %%
import pandas as pd

def crear_dataframe(valores, años, paises, nombre_columna):    
    # Crear la lista para almacenar las filas de datos
    datos_lista = []
    
    # Variable para iterar sobre los valores
    indice_valor = 0
    
    # Iterar sobre los países y años
    for id_pais, nombre_pais in paises.items():  # Iterar sobre los países
        for año in años:  # Iterar sobre los años disponibles
            if indice_valor < len(valores):
                print(f"Valor original antes de agregar (País: {nombre_pais}, Año: {año}): {valores[indice_valor]}")
                # Si hay un valor disponible, añadirlo a la fila
                fila = {
                    "Año": año,
                    "País": nombre_pais,
                    nombre_columna: valores[indice_valor]
                }
                indice_valor += 1
            else:
                # Si no hay más valores, completar con None
                fila = {
                    "Año": año,
                    "País": nombre_pais,
                    nombre_columna: None
                }
            datos_lista.append(fila)  # Añadir la fila a la lista
    
    # Convertir la lista a un DataFrame
    df = pd.DataFrame(datos_lista)
    
    return df

# %% [markdown]
# ## Obtención de datos del Parkinson (varibale independiente)

# %%
import pandas as pd
import requests

# URLs de la API
DATA_URL = "https://api.ourworldindata.org/v1/indicators/916408.data.json"
METADATA_URL = "https://api.ourworldindata.org/v1/indicators/916408.metadata.json"
datos, metadata = cargar_datos()  
valores, años, paises = procesar_datos(datos, metadata) 
df_parkinson = crear_dataframe(valores, años, paises,"Parkinson") 

# Mostrar los resultados en un display
display(df_parkinson)
# Out:
#        Año           País   Parkinson
# 0     1990       Cambodia   21.533830
# 1     1991       Cambodia   21.483840
# 2     1992       Cambodia   21.502138
# 3     1993       Cambodia   21.607151
# 4     1994       Cambodia   21.767658
# ...    ...            ...         ...
# 7291  2017  South America  101.905710
# 7292  2018  South America  105.467110
# 7293  2019  South America  108.644905
# 7294  2020  South America  110.542580
# 7295  2021  South America  115.628784
#
# [7296 rows x 3 columns]

# %% [markdown]
# ## Obtención de datos de la tasa contaminación del aire (varibale independiente)

# %%
import pandas as pd
import requests

# URLs de la API
DATA_URL = "https://api.ourworldindata.org/v1/indicators/939832.data.json"
METADATA_URL = "https://api.ourworldindata.org/v1/indicators/939832.metadata.json"
datos, metadata = cargar_datos()  
valores, años, paises = procesar_datos(datos, metadata) 
df_aire = crear_dataframe(valores, años, paises,"Contaminacion_aire") 

# Mostrar los resultados en un display
display(df_aire)
# Out:
#        Año         País  Contaminacion_aire
# 0     1990  Afghanistan            9.830483
# 1     1991  Afghanistan            9.412167
# 2     1992  Afghanistan            8.970597
# 3     1993  Afghanistan            8.853374
# 4     1994  Afghanistan            9.138245
# ...    ...          ...                 ...
# 7099  2017     Zimbabwe            2.167512
# 7100  2018     Zimbabwe            2.128228
# 7101  2019     Zimbabwe            2.164050
# 7102  2020     Zimbabwe            2.195074
# 7103  2021     Zimbabwe            2.110314
#
# [7104 rows x 3 columns]

# %% [markdown]
# ## Obtención de datos de las muertes atribuidas a fuentes de agua inseguras, calidad de agua (varibale independiente)

# %%
import pandas as pd
import requests

DATA_URL = "https://api.ourworldindata.org/v1/indicators/936533.data.json"
METADATA_URL = "https://api.ourworldindata.org/v1/indicators/936533.metadata.json"
datos, metadata = cargar_datos()  
valores, años, paises = procesar_datos(datos, metadata) 
df_agua = crear_dataframe(valores, años, paises,"Muertes_agua") 

# Mostrar los resultados en un display
display(df_agua)
# Out:
#        Año         País  Muertes_agua
# 0     1990  Afghanistan     5876.4130
# 1     1991  Afghanistan     6145.5880
# 2     1992  Afghanistan     6818.0254
# 3     1993  Afghanistan     8395.5060
# 4     1994  Afghanistan     8754.6260
# ...    ...          ...           ...
# 7291  2017     Zimbabwe     3928.3027
# 7292  2018     Zimbabwe     3940.3884
# 7293  2019     Zimbabwe     3856.9373
# 7294  2020     Zimbabwe     3784.6410
# 7295  2021     Zimbabwe     3834.5771
#
# [7296 rows x 3 columns]

# %% [markdown]
# ## Obtención de datos de la exposición al plomo (varibale independiente)

# %%
import pandas as pd
import requests

DATA_URL = "https://api.ourworldindata.org/v1/indicators/941463.data.json"
METADATA_URL = "https://api.ourworldindata.org/v1/indicators/941463.metadata.json"
datos, metadata = cargar_datos()  
valores, años, paises = procesar_datos(datos, metadata) 
df_plomo = crear_dataframe(valores, años, paises,"Exp_plomo") 

# Mostrar los resultados en un display
display(df_plomo)
# Out:
#        Año         País   Exp_plomo
# 0     1990  Afghanistan  2765.59400
# 1     1991  Afghanistan  2773.61840
# 2     1992  Afghanistan  2782.52610
# 3     1993  Afghanistan  2818.00600
# 4     1994  Afghanistan  2869.15920
# ...    ...          ...         ...
# 7099  2017     Zimbabwe   759.63760
# 7100  2018     Zimbabwe   755.67847
# 7101  2019     Zimbabwe   749.21820
# 7102  2020     Zimbabwe   739.96454
# 7103  2021     Zimbabwe   709.65390
#
# [7104 rows x 3 columns]

# %% [markdown]
# ## Obtención de datos del uso de pepticidas (varibale independiente)

# %%
import pandas as pd
import requests

DATA_URL = "https://api.ourworldindata.org/v1/indicators/1016584.data.json"
METADATA_URL = "https://api.ourworldindata.org/v1/indicators/1016584.metadata.json"
datos, metadata = cargar_datos()  
valores, años, paises = procesar_datos(datos, metadata) 
df_pepticidas = crear_dataframe(valores, años, paises,"Pepticidas") 

# Mostrar los resultados en un display
display(df_pepticidas)
# Out:
# Valor original antes de agregar (País: Africa (FAO), Año: 1990): 73504.69
# Valor original antes de agregar (País: Africa (FAO), Año: 1991): 69490.83
# Valor original antes de agregar (País: Africa (FAO), Año: 1992): 59769.13
# Valor original antes de agregar (País: Africa (FAO), Año: 1993): 53768.65
# Valor original antes de agregar (País: Africa (FAO), Año: 1994): 58312.42
# Valor original antes de agregar (País: Africa (FAO), Año: 1995): 64426.54
# Valor original antes de agregar (País: Africa (FAO), Año: 1996): 66678.48
# Valor original antes de agregar (País: Africa (FAO), Año: 1997): 71455.93
# Valor original antes de agregar (País: Africa (FAO), Año: 1998): 73631.57
# Valor original antes de agregar (País: Africa (FAO), Año: 1999): 75315.72
# Valor original antes de agregar (País: Africa (FAO), Año: 2000): 73352.77
# Valor original antes de agregar (País: Africa (FAO), Año: 2001): 73533.03
# Valor original antes de agregar (País: Africa (FAO), Año: 2002): 81030.17
# Valor original antes de agregar (País: Africa (FAO), Año: 2003): 86364.5
# Valor original antes de agregar (País: Africa (FAO), Año: 2004): 94554.2
# Valor original antes de agregar (País: Africa (FAO), Año: 2005): 98216.13
# Valor original antes de agregar (País: Africa (FAO), Año: 2006): 101493.29
# Valor original antes de agregar (País: Africa (FAO), Año: 2007): 98445.15
# Valor original antes de agregar (País: Africa (FAO), Año: 2008): 107698.76
# Valor original antes de agregar (País: Africa (FAO), Año: 2009): 114249.87
# Valor original antes de agregar (País: Africa (FAO), Año: 2010): 130881.39
# Valor original antes de agregar (País: Africa (FAO), Año: 2011): 143552.97
# Valor original antes de agregar (País: Africa (FAO), Año: 2012): 154408.06
# Valor original antes de agregar (País: Africa (FAO), Año: 2013): 166385.8
# Valor original antes de agregar (País: Africa (FAO), Año: 2014): 164138.6
# Valor original antes de agregar (País: Africa (FAO), Año: 2015): 158492.48
# Valor original antes de agregar (País: Africa (FAO), Año: 2016): 155186.98
# Valor original antes de agregar (País: Africa (FAO), Año: 2017): 170384.19
# Valor original antes de agregar (País: Africa (FAO), Año: 2018): 191049.62
# Valor original antes de agregar (País: Africa (FAO), Año: 2019): 202799.42
# Valor original antes de agregar (País: Africa (FAO), Año: 2020): 210627.6
# Valor original antes de agregar (País: Africa (FAO), Año: 2021): 209957.47
# Valor original antes de agregar (País: Africa (FAO), Año: 2022): 209418.48
# Valor original antes de agregar (País: Albania, Año: 1990): 121
# Valor original antes de agregar (País: Albania, Año: 1991): 121
# Valor original antes de agregar (País: Albania, Año: 1992): 121
# Valor original antes de agregar (País: Albania, Año: 1993): 121
# Valor original antes de agregar (País: Albania, Año: 1994): 201
# Valor original antes de agregar (País: Albania, Año: 1995): 251
# Valor original antes de agregar (País: Albania, Año: 1996): 262.4
# Valor original antes de agregar (País: Albania, Año: 1997): 273.79
# Valor original antes de agregar (País: Albania, Año: 1998): 285.19
# Valor original antes de agregar (País: Albania, Año: 1999): 296.59
# Valor original antes de agregar (País: Albania, Año: 2000): 307.98
# Valor original antes de agregar (País: Albania, Año: 2001): 319.38
# Valor original antes de agregar (País: Albania, Año: 2002): 330.78
# Valor original antes de agregar (País: Albania, Año: 2003): 342.17
# Valor original antes de agregar (País: Albania, Año: 2004): 353.57
# Valor original antes de agregar (País: Albania, Año: 2005): 364.97
# Valor original antes de agregar (País: Albania, Año: 2006): 376.36
# Valor original antes de agregar (País: Albania, Año: 2007): 387.76
# Valor original antes de agregar (País: Albania, Año: 2008): 399.16
# Valor original antes de agregar (País: Albania, Año: 2009): 410.55
# Valor original antes de agregar (País: Albania, Año: 2010): 590.5
# Valor original antes de agregar (País: Albania, Año: 2011): 582.68
# Valor original antes de agregar (País: Albania, Año: 2012): 361.62
# Valor original antes de agregar (País: Albania, Año: 2013): 450.6
# Valor original antes de agregar (País: Albania, Año: 2014): 457.47
# Valor original antes de agregar (País: Albania, Año: 2015): 538.24
# Valor original antes de agregar (País: Albania, Año: 2016): 584.49
# Valor original antes de agregar (País: Albania, Año: 2017): 614.91
# Valor original antes de agregar (País: Albania, Año: 2018): 442.35
# Valor original antes de agregar (País: Albania, Año: 2019): 746.36
# Valor original antes de agregar (País: Albania, Año: 2020): 401.58
# Valor original antes de agregar (País: Albania, Año: 2021): 433.3
# Valor original antes de agregar (País: Albania, Año: 2022): 295.61
# Valor original antes de agregar (País: Algeria, Año: 1990): 5743.46
# Valor original antes de agregar (País: Algeria, Año: 1991): 7094.39
# Valor original antes de agregar (País: Algeria, Año: 1992): 3876.18
# Valor original antes de agregar (País: Algeria, Año: 1993): 3710
# Valor original antes de agregar (País: Algeria, Año: 1994): 4058.62
# Valor original antes de agregar (País: Algeria, Año: 1995): 6255.63
# Valor original antes de agregar (País: Algeria, Año: 1996): 2190.88
# Valor original antes de agregar (País: Algeria, Año: 1997): 1822.16
# Valor original antes de agregar (País: Algeria, Año: 1998): 1498.96
# Valor original antes de agregar (País: Algeria, Año: 1999): 2228.17
# Valor original antes de agregar (País: Algeria, Año: 2000): 2537.4
# Valor original antes de agregar (País: Algeria, Año: 2001): 2846.64
# Valor original antes de agregar (País: Algeria, Año: 2002): 3155.87
# Valor original antes de agregar (País: Algeria, Año: 2003): 3465.11
# Valor original antes de agregar (País: Algeria, Año: 2004): 3774.35
# Valor original antes de agregar (País: Algeria, Año: 2005): 2810.61
# Valor original antes de agregar (País: Algeria, Año: 2006): 2504.01
# Valor original antes de agregar (País: Algeria, Año: 2007): 3562.52
# Valor original antes de agregar (País: Algeria, Año: 2008): 5720.11
# Valor original antes de agregar (País: Algeria, Año: 2009): 3168.41
# Valor original antes de agregar (País: Algeria, Año: 2010): 1869.58
# Valor original antes de agregar (País: Algeria, Año: 2011): 7612.21
# Valor original antes de agregar (País: Algeria, Año: 2012): 8980.17
# Valor original antes de agregar (País: Algeria, Año: 2013): 8269.57
# Valor original antes de agregar (País: Algeria, Año: 2014): 7151.52
# Valor original antes de agregar (País: Algeria, Año: 2015): 4516.93
# Valor original antes de agregar (País: Algeria, Año: 2016): 4153.38
# Valor original antes de agregar (País: Algeria, Año: 2017): 6067.35
# Valor original antes de agregar (País: Algeria, Año: 2018): 6067.35
# Valor original antes de agregar (País: Algeria, Año: 2019): 6067.35
# Valor original antes de agregar (País: Algeria, Año: 2020): 6067.35
# Valor original antes de agregar (País: Algeria, Año: 2021): 6067.35
# Valor original antes de agregar (País: Algeria, Año: 2022): 6067.35
# Valor original antes de agregar (País: Americas (FAO), Año: 1990): 608290.06
# Valor original antes de agregar (País: Americas (FAO), Año: 1991): 608969.1
# Valor original antes de agregar (País: Americas (FAO), Año: 1992): 626125.75
# Valor original antes de agregar (País: Americas (FAO), Año: 1993): 626321.5
# Valor original antes de agregar (País: Americas (FAO), Año: 1994): 679342.56
# Valor original antes de agregar (País: Americas (FAO), Año: 1995): 703380.3
# Valor original antes de agregar (País: Americas (FAO), Año: 1996): 745473.8
# Valor original antes de agregar (País: Americas (FAO), Año: 1997): 787561.56
# Valor original antes de agregar (País: Americas (FAO), Año: 1998): 834331.25
# Valor original antes de agregar (País: Americas (FAO), Año: 1999): 857809.7
# Valor original antes de agregar (País: Americas (FAO), Año: 2000): 890321.5
# Valor original antes de agregar (País: Americas (FAO), Año: 2001): 894427.06
# Valor original antes de agregar (País: Americas (FAO), Año: 2002): 878610.9
# Valor original antes de agregar (País: Americas (FAO), Año: 2003): 962220.75
# Valor original antes de agregar (País: Americas (FAO), Año: 2004): 1044406.25
# Valor original antes de agregar (País: Americas (FAO), Año: 2005): 1095995.8
# Valor original antes de agregar (País: Americas (FAO), Año: 2006): 1069857
# Valor original antes de agregar (País: Americas (FAO), Año: 2007): 1208808
# Valor original antes de agregar (País: Americas (FAO), Año: 2008): 1189188.5
# Valor original antes de agregar (País: Americas (FAO), Año: 2009): 1121804.4
# Valor original antes de agregar (País: Americas (FAO), Año: 2010): 1299765.4
# Valor original antes de agregar (País: Americas (FAO), Año: 2011): 1340086.2
# Valor original antes de agregar (País: Americas (FAO), Año: 2012): 1408289.5
# Valor original antes de agregar (País: Americas (FAO), Año: 2013): 1446133.1
# Valor original antes de agregar (País: Americas (FAO), Año: 2014): 1472978
# Valor original antes de agregar (País: Americas (FAO), Año: 2015): 1456410.5
# Valor original antes de agregar (País: Americas (FAO), Año: 2016): 1508930.8
# Valor original antes de agregar (País: Americas (FAO), Año: 2017): 1530867.8
# Valor original antes de agregar (País: Americas (FAO), Año: 2018): 1540627.6
# Valor original antes de agregar (País: Americas (FAO), Año: 2019): 1665984.2
# Valor original antes de agregar (País: Americas (FAO), Año: 2020): 1728278
# Valor original antes de agregar (País: Americas (FAO), Año: 2021): 1710668.1
# Valor original antes de agregar (País: Americas (FAO), Año: 2022): 1887223
# Valor original antes de agregar (País: Andorra, Año: 1990): 14.12
# Valor original antes de agregar (País: Andorra, Año: 1991): 14.12
# Valor original antes de agregar (País: Andorra, Año: 1992): 14.12
# Valor original antes de agregar (País: Andorra, Año: 1993): 14.12
# Valor original antes de agregar (País: Andorra, Año: 1994): 14.12
# Valor original antes de agregar (País: Andorra, Año: 1995): 12.82
# Valor original antes de agregar (País: Andorra, Año: 1996): 12.33
# Valor original antes de agregar (País: Andorra, Año: 1997): 14.17
# Valor original antes de agregar (País: Andorra, Año: 1998): 15.4
# Valor original antes de agregar (País: Andorra, Año: 1999): 15.12
# Valor original antes de agregar (País: Andorra, Año: 2000): 18.55
# Valor original antes de agregar (País: Andorra, Año: 2001): 18
# Valor original antes de agregar (País: Andorra, Año: 2002): 18.43
# Valor original antes de agregar (País: Andorra, Año: 2003): 11.74
# Valor original antes de agregar (País: Andorra, Año: 2004): 11.79
# Valor original antes de agregar (País: Andorra, Año: 2005): 12.4
# Valor original antes de agregar (País: Andorra, Año: 2006): 14.58
# Valor original antes de agregar (País: Andorra, Año: 2007): 15.01
# Valor original antes de agregar (País: Andorra, Año: 2008): 14.93
# Valor original antes de agregar (País: Andorra, Año: 2009): 13.39
# Valor original antes de agregar (País: Andorra, Año: 2010): 12.72
# Valor original antes de agregar (País: Andorra, Año: 2011): 13.44
# Valor original antes de agregar (País: Andorra, Año: 2012): 13.68
# Valor original antes de agregar (País: Andorra, Año: 2013): 17.26
# Valor original antes de agregar (País: Andorra, Año: 2014): 15.42
# Valor original antes de agregar (País: Andorra, Año: 2015): 16.28
# Valor original antes de agregar (País: Andorra, Año: 2016): 13.39
# Valor original antes de agregar (País: Andorra, Año: 2017): 13.93
# Valor original antes de agregar (País: Andorra, Año: 2018): 13.55
# Valor original antes de agregar (País: Andorra, Año: 2019): 14.38
# Valor original antes de agregar (País: Andorra, Año: 2020): 16.26
# Valor original antes de agregar (País: Andorra, Año: 2021): 17.3
# Valor original antes de agregar (País: Andorra, Año: 2022): 17.82
# Valor original antes de agregar (País: Angola, Año: 1990): 64
# Valor original antes de agregar (País: Angola, Año: 1991): 79
# Valor original antes de agregar (País: Angola, Año: 1992): 23
# Valor original antes de agregar (País: Angola, Año: 1993): 169
# Valor original antes de agregar (País: Angola, Año: 1994): 89.5
# Valor original antes de agregar (País: Angola, Año: 1995): 336
# Valor original antes de agregar (País: Angola, Año: 1996): 40
# Valor original antes de agregar (País: Angola, Año: 1997): 40
# Valor original antes de agregar (País: Angola, Año: 1998): 40
# Valor original antes de agregar (País: Angola, Año: 1999): 40
# Valor original antes de agregar (País: Angola, Año: 2000): 40
# Valor original antes de agregar (País: Angola, Año: 2001): 40
# Valor original antes de agregar (País: Angola, Año: 2002): 40
# Valor original antes de agregar (País: Angola, Año: 2003): 40
# Valor original antes de agregar (País: Angola, Año: 2004): 40
# Valor original antes de agregar (País: Angola, Año: 2005): 40
# Valor original antes de agregar (País: Angola, Año: 2006): 40
# Valor original antes de agregar (País: Angola, Año: 2007): 40
# Valor original antes de agregar (País: Angola, Año: 2008): 40
# Valor original antes de agregar (País: Angola, Año: 2009): 40
# Valor original antes de agregar (País: Angola, Año: 2010): 40
# Valor original antes de agregar (País: Angola, Año: 2011): 40
# Valor original antes de agregar (País: Angola, Año: 2012): 40
# Valor original antes de agregar (País: Angola, Año: 2013): 40
# Valor original antes de agregar (País: Angola, Año: 2014): 40
# Valor original antes de agregar (País: Angola, Año: 2015): 40
# Valor original antes de agregar (País: Angola, Año: 2016): 40
# Valor original antes de agregar (País: Angola, Año: 2017): 40
# Valor original antes de agregar (País: Angola, Año: 2018): 40
# Valor original antes de agregar (País: Angola, Año: 2019): 40
# Valor original antes de agregar (País: Angola, Año: 2020): 40
# Valor original antes de agregar (País: Angola, Año: 2021): 40
# Valor original antes de agregar (País: Angola, Año: 2022): 40
# Valor original antes de agregar (País: Anguilla, Año: 1990): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1991): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1992): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1993): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1994): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1995): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1996): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1997): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1998): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 1999): 23.06
# Valor original antes de agregar (País: Anguilla, Año: 2000): 22.33
# Valor original antes de agregar (País: Anguilla, Año: 2001): 23.11
# Valor original antes de agregar (País: Anguilla, Año: 2002): 23.82
# Valor original antes de agregar (País: Anguilla, Año: 2003): 24.63
# Valor original antes de agregar (País: Anguilla, Año: 2004): 26.3
# Valor original antes de agregar (País: Anguilla, Año: 2005): 30.45
# Valor original antes de agregar (País: Anguilla, Año: 2006): 36.8
# Valor original antes de agregar (País: Anguilla, Año: 2007): 48.62
# Valor original antes de agregar (País: Anguilla, Año: 2008): 58.04
# Valor original antes de agregar (País: Anguilla, Año: 2009): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2010): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2011): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2012): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2013): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2014): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2015): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2016): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2017): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2018): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2019): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2020): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2021): 65.91
# Valor original antes de agregar (País: Anguilla, Año: 2022): 65.91
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1990): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1991): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1992): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1993): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1994): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1995): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1996): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1997): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1998): 289.45
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 1999): 265.94
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2000): 260.2
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2001): 272.21
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2002): 325.49
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2003): 378.77
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2004): 432.05
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2005): 410.49
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2006): 347.26
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2007): 291.81
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2008): 318.99
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2009): 379.81
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2010): 341.78
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2011): 781.95
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2012): 694.16
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2013): 685.08
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2014): 174.47
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2015): 175.93
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2016): 180.2
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2017): 182.95
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2018): 199.78
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2019): 219.63
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2020): 250.02
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2021): 250.94
# Valor original antes de agregar (País: Antigua and Barbuda, Año: 2022): 251.4
# Valor original antes de agregar (País: Argentina, Año: 1990): 26156
# Valor original antes de agregar (País: Argentina, Año: 1991): 26156
# Valor original antes de agregar (País: Argentina, Año: 1992): 26156
# Valor original antes de agregar (País: Argentina, Año: 1993): 26156
# Valor original antes de agregar (País: Argentina, Año: 1994): 30195
# Valor original antes de agregar (País: Argentina, Año: 1995): 37842
# Valor original antes de agregar (País: Argentina, Año: 1996): 54595
# Valor original antes de agregar (País: Argentina, Año: 1997): 77691
# Valor original antes de agregar (País: Argentina, Año: 1998): 62397
# Valor original antes de agregar (País: Argentina, Año: 1999): 73293.04
# Valor original antes de agregar (País: Argentina, Año: 2000): 84189.08
# Valor original antes de agregar (País: Argentina, Año: 2001): 95085.12
# Valor original antes de agregar (País: Argentina, Año: 2002): 105981.16
# Valor original antes de agregar (País: Argentina, Año: 2003): 116877.2
# Valor original antes de agregar (País: Argentina, Año: 2004): 127773.24
# Valor original antes de agregar (País: Argentina, Año: 2005): 138669.28
# Valor original antes de agregar (País: Argentina, Año: 2006): 149565.31
# Valor original antes de agregar (País: Argentina, Año: 2007): 186790.19
# Valor original antes de agregar (País: Argentina, Año: 2008): 203369.34
# Valor original antes de agregar (País: Argentina, Año: 2009): 140094.8
# Valor original antes de agregar (País: Argentina, Año: 2010): 235739.1
# Valor original antes de agregar (País: Argentina, Año: 2011): 220610.05
# Valor original antes de agregar (País: Argentina, Año: 2012): 216308.7
# Valor original antes de agregar (País: Argentina, Año: 2013): 212007.34
# Valor original antes de agregar (País: Argentina, Año: 2014): 207706
# Valor original antes de agregar (País: Argentina, Año: 2015): 203807
# Valor original antes de agregar (País: Argentina, Año: 2016): 199908
# Valor original antes de agregar (País: Argentina, Año: 2017): 196009
# Valor original antes de agregar (País: Argentina, Año: 2018): 172928
# Valor original antes de agregar (País: Argentina, Año: 2019): 204559
# Valor original antes de agregar (País: Argentina, Año: 2020): 241294.19
# Valor original antes de agregar (País: Argentina, Año: 2021): 241519.98
# Valor original antes de agregar (País: Argentina, Año: 2022): 262506.94
# Valor original antes de agregar (País: Armenia, Año: 1990): 8
# Valor original antes de agregar (País: Armenia, Año: 1991): 8
# Valor original antes de agregar (País: Armenia, Año: 1992): 23
# Valor original antes de agregar (País: Armenia, Año: 1993): 23.9
# Valor original antes de agregar (País: Armenia, Año: 1994): 32
# Valor original antes de agregar (País: Armenia, Año: 1995): 41.46
# Valor original antes de agregar (País: Armenia, Año: 1996): 50.92
# Valor original antes de agregar (País: Armenia, Año: 1997): 60.38
# Valor original antes de agregar (País: Armenia, Año: 1998): 69.85
# Valor original antes de agregar (País: Armenia, Año: 1999): 79.31
# Valor original antes de agregar (País: Armenia, Año: 2000): 88.77
# Valor original antes de agregar (País: Armenia, Año: 2001): 98.23
# Valor original antes de agregar (País: Armenia, Año: 2002): 204.77
# Valor original antes de agregar (País: Armenia, Año: 2003): 220.51
# Valor original antes de agregar (País: Armenia, Año: 2004): 227.55
# Valor original antes de agregar (País: Armenia, Año: 2005): 241.71
# Valor original antes de agregar (País: Armenia, Año: 2006): 218.2
# Valor original antes de agregar (País: Armenia, Año: 2007): 198.36
# Valor original antes de agregar (País: Armenia, Año: 2008): 278.72
# Valor original antes de agregar (País: Armenia, Año: 2009): 320.67
# Valor original antes de agregar (País: Armenia, Año: 2010): 362.62
# Valor original antes de agregar (País: Armenia, Año: 2011): 404.57
# Valor original antes de agregar (País: Armenia, Año: 2012): 446.52
# Valor original antes de agregar (País: Armenia, Año: 2013): 488.47
# Valor original antes de agregar (País: Armenia, Año: 2014): 530.42
# Valor original antes de agregar (País: Armenia, Año: 2015): 572.37
# Valor original antes de agregar (País: Armenia, Año: 2016): 614.32
# Valor original antes de agregar (País: Armenia, Año: 2017): 527.33
# Valor original antes de agregar (País: Armenia, Año: 2018): 639.15
# Valor original antes de agregar (País: Armenia, Año: 2019): 914.03
# Valor original antes de agregar (País: Armenia, Año: 2020): 891.82
# Valor original antes de agregar (País: Armenia, Año: 2021): 148.21
# Valor original antes de agregar (País: Armenia, Año: 2022): 155.18
# Valor original antes de agregar (País: Aruba, Año: 1990): 169.1
# Valor original antes de agregar (País: Aruba, Año: 1991): 189.98
# Valor original antes de agregar (País: Aruba, Año: 1992): 210.87
# Valor original antes de agregar (País: Aruba, Año: 1993): 231.75
# Valor original antes de agregar (País: Aruba, Año: 1994): 252.64
# Valor original antes de agregar (País: Aruba, Año: 1995): 273.52
# Valor original antes de agregar (País: Aruba, Año: 1996): 294.41
# Valor original antes de agregar (País: Aruba, Año: 1997): 315.3
# Valor original antes de agregar (País: Aruba, Año: 1998): 336.18
# Valor original antes de agregar (País: Aruba, Año: 1999): 357.07
# Valor original antes de agregar (País: Aruba, Año: 2000): 377.95
# Valor original antes de agregar (País: Aruba, Año: 2001): 398.84
# Valor original antes de agregar (País: Aruba, Año: 2002): 419.72
# Valor original antes de agregar (País: Aruba, Año: 2003): 440.61
# Valor original antes de agregar (País: Aruba, Año: 2004): 461.49
# Valor original antes de agregar (País: Aruba, Año: 2005): 482.38
# Valor original antes de agregar (País: Aruba, Año: 2006): 503.26
# Valor original antes de agregar (País: Aruba, Año: 2007): 524.81
# Valor original antes de agregar (País: Aruba, Año: 2008): 537.55
# Valor original antes de agregar (País: Aruba, Año: 2009): 501.68
# Valor original antes de agregar (País: Aruba, Año: 2010): 458.58
# Valor original antes de agregar (País: Aruba, Año: 2011): 410.08
# Valor original antes de agregar (País: Aruba, Año: 2012): 390.52
# Valor original antes de agregar (País: Aruba, Año: 2013): 454.47
# Valor original antes de agregar (País: Aruba, Año: 2014): 459.14
# Valor original antes de agregar (País: Aruba, Año: 2015): 466.78
# Valor original antes de agregar (País: Aruba, Año: 2016): 387.96
# Valor original antes de agregar (País: Aruba, Año: 2017): 403.88
# Valor original antes de agregar (País: Aruba, Año: 2018): 457.71
# Valor original antes de agregar (País: Aruba, Año: 2019): 491.17
# Valor original antes de agregar (País: Aruba, Año: 2020): 507.91
# Valor original antes de agregar (País: Aruba, Año: 2021): 598343.94
# Valor original antes de agregar (País: Aruba, Año: 2022): 600799.3
# Valor original antes de agregar (País: Asia (FAO), Año: 1990): 638281.56
# Valor original antes de agregar (País: Asia (FAO), Año: 1991): 644808.7
# Valor original antes de agregar (País: Asia (FAO), Año: 1992): 665730.1
# Valor original antes de agregar (País: Asia (FAO), Año: 1993): 703033.8
# Valor original antes de agregar (País: Asia (FAO), Año: 1994): 717419.56
# Valor original antes de agregar (País: Asia (FAO), Año: 1995): 721390.75
# Valor original antes de agregar (País: Asia (FAO), Año: 1996): 700540.2
# Valor original antes de agregar (País: Asia (FAO), Año: 1997): 728425.75
# Valor original antes de agregar (País: Asia (FAO), Año: 1998): 726608.06
# Valor original antes de agregar (País: Asia (FAO), Año: 1999): 736336.3
# Valor original antes de agregar (País: Asia (FAO), Año: 2000): 763502.06
# Valor original antes de agregar (País: Asia (FAO), Año: 2001): 797398.44
# Valor original antes de agregar (País: Asia (FAO), Año: 2002): 826778.7
# Valor original antes de agregar (País: Asia (FAO), Año: 2003): 840870.1
# Valor original antes de agregar (País: Asia (FAO), Año: 2004): 861999.3
# Valor original antes de agregar (País: Asia (FAO), Año: 2005): 961650.7
# Valor original antes de agregar (País: Asia (FAO), Año: 2006): 992915.9
# Valor original antes de agregar (País: Asia (FAO), Año: 2007): 1022739.7
# Valor original antes de agregar (País: Asia (FAO), Año: 2008): 1101974.8
# Valor original antes de agregar (País: Asia (FAO), Año: 2009): 1015344.56
# Valor original antes de agregar (País: Asia (FAO), Año: 2010): 1070554.8
# Valor original antes de agregar (País: Asia (FAO), Año: 2011): 1088470.9
# Valor original antes de agregar (País: Asia (FAO), Año: 2012): 1054764.2
# Valor original antes de agregar (País: Asia (FAO), Año: 2013): 1131639.9
# Valor original antes de agregar (País: Asia (FAO), Año: 2014): 1181472.8
# Valor original antes de agregar (País: Asia (FAO), Año: 2015): 1079411.2
# Valor original antes de agregar (País: Asia (FAO), Año: 2016): 1091053.1
# Valor original antes de agregar (País: Asia (FAO), Año: 2017): 1075868.1
# Valor original antes de agregar (País: Asia (FAO), Año: 2018): 941238.4
# Valor original antes de agregar (País: Asia (FAO), Año: 2019): 1066928.6
# Valor original antes de agregar (País: Asia (FAO), Año: 2020): 1054017.8
# Valor original antes de agregar (País: Asia (FAO), Año: 2021): 17866.68
# Valor original antes de agregar (País: Asia (FAO), Año: 2022): 17866.68
# Valor original antes de agregar (País: Australia, Año: 1990): 22235.39
# Valor original antes de agregar (País: Australia, Año: 1991): 23898.78
# Valor original antes de agregar (País: Australia, Año: 1992): 21056.74
# Valor original antes de agregar (País: Australia, Año: 1993): 25598.14
# Valor original antes de agregar (País: Australia, Año: 1994): 31185.35
# Valor original antes de agregar (País: Australia, Año: 1995): 34091.81
# Valor original antes de agregar (País: Australia, Año: 1996): 37215.04
# Valor original antes de agregar (País: Australia, Año: 1997): 34200
# Valor original antes de agregar (País: Australia, Año: 1998): 33475.36
# Valor original antes de agregar (País: Australia, Año: 1999): 32709.67
# Valor original antes de agregar (País: Australia, Año: 2000): 26650.45
# Valor original antes de agregar (País: Australia, Año: 2001): 32417.64
# Valor original antes de agregar (País: Australia, Año: 2002): 36276.8
# Valor original antes de agregar (País: Australia, Año: 2003): 34309.93
# Valor original antes de agregar (País: Australia, Año: 2004): 35901.14
# Valor original antes de agregar (País: Australia, Año: 2005): 32446.24
# Valor original antes de agregar (País: Australia, Año: 2006): 42935.38
# Valor original antes de agregar (País: Australia, Año: 2007): 38065.69
# Valor original antes de agregar (País: Australia, Año: 2008): 42169.39
# Valor original antes de agregar (País: Australia, Año: 2009): 47632.99
# Valor original antes de agregar (País: Australia, Año: 2010): 48687.87
# Valor original antes de agregar (País: Australia, Año: 2011): 45177.19
# Valor original antes de agregar (País: Australia, Año: 2012): 49857.35
# Valor original antes de agregar (País: Australia, Año: 2013): 50921.6
# Valor original antes de agregar (País: Australia, Año: 2014): 63416.48
# Valor original antes de agregar (País: Australia, Año: 2015): 59634
# Valor original antes de agregar (País: Australia, Año: 2016): 59634
# Valor original antes de agregar (País: Australia, Año: 2017): 59634
# Valor original antes de agregar (País: Australia, Año: 2018): 59634
# Valor original antes de agregar (País: Australia, Año: 2019): 59634
# Valor original antes de agregar (País: Australia, Año: 2020): 59634
# Valor original antes de agregar (País: Australia, Año: 2021): 4246
# Valor original antes de agregar (País: Australia, Año: 2022): 4487
# Valor original antes de agregar (País: Austria, Año: 1990): 3897
# Valor original antes de agregar (País: Austria, Año: 1991): 3984
# Valor original antes de agregar (País: Austria, Año: 1992): 3619
# Valor original antes de agregar (País: Austria, Año: 1993): 3402
# Valor original antes de agregar (País: Austria, Año: 1994): 3565
# Valor original antes de agregar (País: Austria, Año: 1995): 3689.6
# Valor original antes de agregar (País: Austria, Año: 1996): 3340.3
# Valor original antes de agregar (País: Austria, Año: 1997): 3418.6
# Valor original antes de agregar (País: Austria, Año: 1998): 3563.2
# Valor original antes de agregar (País: Austria, Año: 1999): 3132.2
# Valor original antes de agregar (País: Austria, Año: 2000): 3079.2
# Valor original antes de agregar (País: Austria, Año: 2001): 3384.9
# Valor original antes de agregar (País: Austria, Año: 2002): 3301.7
# Valor original antes de agregar (País: Austria, Año: 2003): 3404
# Valor original antes de agregar (País: Austria, Año: 2004): 3415.7
# Valor original antes de agregar (País: Austria, Año: 2005): 3526.6
# Valor original antes de agregar (País: Austria, Año: 2006): 4246.7
# Valor original antes de agregar (País: Austria, Año: 2007): 3531.8
# Valor original antes de agregar (País: Austria, Año: 2008): 3692.4
# Valor original antes de agregar (País: Austria, Año: 2009): 3441.5
# Valor original antes de agregar (País: Austria, Año: 2010): 3563.3
# Valor original antes de agregar (País: Austria, Año: 2011): 3097.44
# Valor original antes de agregar (País: Austria, Año: 2012): 3373.22
# Valor original antes de agregar (País: Austria, Año: 2013): 3777.62
# Valor original antes de agregar (País: Austria, Año: 2014): 4361.49
# Valor original antes de agregar (País: Austria, Año: 2015): 4624.88
# Valor original antes de agregar (País: Austria, Año: 2016): 5279.54
# Valor original antes de agregar (País: Austria, Año: 2017): 4954.46
# Valor original antes de agregar (País: Austria, Año: 2018): 5566.03
# Valor original antes de agregar (País: Austria, Año: 2019): 5790.56
# Valor original antes de agregar (País: Austria, Año: 2020): 6068.73
# Valor original antes de agregar (País: Austria, Año: 2021): 148.68
# Valor original antes de agregar (País: Austria, Año: 2022): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1990): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1991): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1992): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1993): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1994): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1995): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1996): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1997): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1998): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 1999): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 2000): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 2001): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 2002): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 2003): 148.68
# Valor original antes de agregar (País: Azerbaijan, Año: 2004): 262.99
# Valor original antes de agregar (País: Azerbaijan, Año: 2005): 316.18
# Valor original antes de agregar (País: Azerbaijan, Año: 2006): 333.85
# Valor original antes de agregar (País: Azerbaijan, Año: 2007): 461.84
# Valor original antes de agregar (País: Azerbaijan, Año: 2008): 516.35
# Valor original antes de agregar (País: Azerbaijan, Año: 2009): 489.8
# Valor original antes de agregar (País: Azerbaijan, Año: 2010): 531.84
# Valor original antes de agregar (País: Azerbaijan, Año: 2011): 529.69
# Valor original antes de agregar (País: Azerbaijan, Año: 2012): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2013): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2014): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2015): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2016): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2017): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2018): 542.82
# Valor original antes de agregar (País: Azerbaijan, Año: 2019): 242
# Valor original antes de agregar (País: Azerbaijan, Año: 2020): 257.1
# Valor original antes de agregar (País: Azerbaijan, Año: 2021): 252.46
# Valor original antes de agregar (País: Azerbaijan, Año: 2022): 313.9
# Valor original antes de agregar (País: Bahamas, Año: 1990): 375.34
# Valor original antes de agregar (País: Bahamas, Año: 1991): 335.15
# Valor original antes de agregar (País: Bahamas, Año: 1992): 437.63
# Valor original antes de agregar (País: Bahamas, Año: 1993): 536.93
# Valor original antes de agregar (País: Bahamas, Año: 1994): 536.29
# Valor original antes de agregar (País: Bahamas, Año: 1995): 554.09
# Valor original antes de agregar (País: Bahamas, Año: 1996): 461.09
# Valor original antes de agregar (País: Bahamas, Año: 1997): 629.38
# Valor original antes de agregar (País: Bahamas, Año: 1998): 547.49
# Valor original antes de agregar (País: Bahamas, Año: 1999): 498.67
# Valor original antes de agregar (País: Bahamas, Año: 2000): 393.78
# Valor original antes de agregar (País: Bahamas, Año: 2001): 436.07
# Valor original antes de agregar (País: Bahamas, Año: 2002): 375.45
# Valor original antes de agregar (País: Bahamas, Año: 2003): 454.09
# Valor original antes de agregar (País: Bahamas, Año: 2004): 243.45
# Valor original antes de agregar (País: Bahamas, Año: 2005): 97.41
# Valor original antes de agregar (País: Bahamas, Año: 2006): 87
# Valor original antes de agregar (País: Bahamas, Año: 2007): 144.36
# Valor original antes de agregar (País: Bahamas, Año: 2008): 158.5
# Valor original antes de agregar (País: Bahamas, Año: 2009): 111.38
# Valor original antes de agregar (País: Bahamas, Año: 2010): 118.48
# Valor original antes de agregar (País: Bahamas, Año: 2011): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2012): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2013): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2014): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2015): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2016): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2017): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2018): 178.05
# Valor original antes de agregar (País: Bahamas, Año: 2019): 14.05
# Valor original antes de agregar (País: Bahamas, Año: 2020): 14.05
# Valor original antes de agregar (País: Bahamas, Año: 2021): 14.05
# Valor original antes de agregar (País: Bahamas, Año: 2022): 14.05
# Valor original antes de agregar (País: Bahrain, Año: 1990): 30.86
# Valor original antes de agregar (País: Bahrain, Año: 1991): 12.46
# Valor original antes de agregar (País: Bahrain, Año: 1992): 12.16
# Valor original antes de agregar (País: Bahrain, Año: 1993): 9.42
# Valor original antes de agregar (País: Bahrain, Año: 1994): 11.15
# Valor original antes de agregar (País: Bahrain, Año: 1995): 12.5
# Valor original antes de agregar (País: Bahrain, Año: 1996): 8.65
# Valor original antes de agregar (País: Bahrain, Año: 1997): 9.2
# Valor original antes de agregar (País: Bahrain, Año: 1998): 0.91
# Valor original antes de agregar (País: Bahrain, Año: 1999): 6.03
# Valor original antes de agregar (País: Bahrain, Año: 2000): 12.24
# Valor original antes de agregar (País: Bahrain, Año: 2001): 12.75
# Valor original antes de agregar (País: Bahrain, Año: 2002): 12.12
# Valor original antes de agregar (País: Bahrain, Año: 2003): 16.25
# Valor original antes de agregar (País: Bahrain, Año: 2004): 10.45
# Valor original antes de agregar (País: Bahrain, Año: 2005): 12.59
# Valor original antes de agregar (País: Bahrain, Año: 2006): 9.84
# Valor original antes de agregar (País: Bahrain, Año: 2007): 9.14
# Valor original antes de agregar (País: Bahrain, Año: 2008): 9.87
# Valor original antes de agregar (País: Bahrain, Año: 2009): 10.59
# Valor original antes de agregar (País: Bahrain, Año: 2010): 11.32
# Valor original antes de agregar (País: Bahrain, Año: 2011): 12.05
# Valor original antes de agregar (País: Bahrain, Año: 2012): 12.78
# Valor original antes de agregar (País: Bahrain, Año: 2013): 13.5
# Valor original antes de agregar (País: Bahrain, Año: 2014): 14.23
# Valor original antes de agregar (País: Bahrain, Año: 2015): 34.03
# Valor original antes de agregar (País: Bahrain, Año: 2016): 31.45
# Valor original antes de agregar (País: Bahrain, Año: 2017): 30.24
# Valor original antes de agregar (País: Bahrain, Año: 2018): 13.6
# Valor original antes de agregar (País: Bahrain, Año: 2019): 1266
# Valor original antes de agregar (País: Bahrain, Año: 2020): 1287
# Valor original antes de agregar (País: Bahrain, Año: 2021): 1453
# Valor original antes de agregar (País: Bahrain, Año: 2022): 1487
# Valor original antes de agregar (País: Bangladesh, Año: 1990): 1594.5
# Valor original antes de agregar (País: Bangladesh, Año: 1991): 1702
# Valor original antes de agregar (País: Bangladesh, Año: 1992): 1919
# Valor original antes de agregar (País: Bangladesh, Año: 1993): 2035
# Valor original antes de agregar (País: Bangladesh, Año: 1994): 2068
# Valor original antes de agregar (País: Bangladesh, Año: 1995): 2532
# Valor original antes de agregar (País: Bangladesh, Año: 1996): 3170
# Valor original antes de agregar (País: Bangladesh, Año: 1997): 3334.84
# Valor original antes de agregar (País: Bangladesh, Año: 1998): 4206.24
# Valor original antes de agregar (País: Bangladesh, Año: 1999): 5462.81
# Valor original antes de agregar (País: Bangladesh, Año: 2000): 6995.51
# Valor original antes de agregar (País: Bangladesh, Año: 2001): 8090.88
# Valor original antes de agregar (País: Bangladesh, Año: 2002): 9412.65
# Valor original antes de agregar (País: Bangladesh, Año: 2003): 10915.12
# Valor original antes de agregar (País: Bangladesh, Año: 2004): 12403.08
# Valor original antes de agregar (País: Bangladesh, Año: 2005): 13755.78
# Valor original antes de agregar (País: Bangladesh, Año: 2006): 13250.83
# Valor original antes de agregar (País: Bangladesh, Año: 2007): 14798.28
# Valor original antes de agregar (País: Bangladesh, Año: 2008): 13289.18
# Valor original antes de agregar (País: Bangladesh, Año: 2009): 15330.16
# Valor original antes de agregar (País: Bangladesh, Año: 2010): 15857.26
# Valor original antes de agregar (País: Bangladesh, Año: 2011): 13364.42
# Valor original antes de agregar (País: Bangladesh, Año: 2012): 14387.63
# Valor original antes de agregar (País: Bangladesh, Año: 2013): 15144.49
# Valor original antes de agregar (País: Bangladesh, Año: 2014): 15265.15
# Valor original antes de agregar (País: Bangladesh, Año: 2015): 15385.81
# Valor original antes de agregar (País: Bangladesh, Año: 2016): 15506.47
# Valor original antes de agregar (País: Bangladesh, Año: 2017): 15506.47
# Valor original antes de agregar (País: Bangladesh, Año: 2018): 15506.47
# Valor original antes de agregar (País: Bangladesh, Año: 2019): 550
# Valor original antes de agregar (País: Bangladesh, Año: 2020): 550
# Valor original antes de agregar (País: Bangladesh, Año: 2021): 550
# Valor original antes de agregar (País: Bangladesh, Año: 2022): 550
# Valor original antes de agregar (País: Barbados, Año: 1990): 514
# Valor original antes de agregar (País: Barbados, Año: 1991): 664
# Valor original antes de agregar (País: Barbados, Año: 1992): 475
# Valor original antes de agregar (País: Barbados, Año: 1993): 168.46
# Valor original antes de agregar (País: Barbados, Año: 1994): 164.29
# Valor original antes de agregar (País: Barbados, Año: 1995): 160.12
# Valor original antes de agregar (País: Barbados, Año: 1996): 155.95
# Valor original antes de agregar (País: Barbados, Año: 1997): 151.78
# Valor original antes de agregar (País: Barbados, Año: 1998): 147.61
# Valor original antes de agregar (País: Barbados, Año: 1999): 143.44
# Valor original antes de agregar (País: Barbados, Año: 2000): 139.28
# Valor original antes de agregar (País: Barbados, Año: 2001): 135.11
# Valor original antes de agregar (País: Barbados, Año: 2002): 130.94
# Valor original antes de agregar (País: Barbados, Año: 2003): 126.77
# Valor original antes de agregar (País: Barbados, Año: 2004): 122.6
# Valor original antes de agregar (País: Barbados, Año: 2005): 118.43
# Valor original antes de agregar (País: Barbados, Año: 2006): 114.26
# Valor original antes de agregar (País: Barbados, Año: 2007): 110.09
# Valor original antes de agregar (País: Barbados, Año: 2008): 105.92
# Valor original antes de agregar (País: Barbados, Año: 2009): 101.75
# Valor original antes de agregar (País: Barbados, Año: 2010): 97.58
# Valor original antes de agregar (País: Barbados, Año: 2011): 93.41
# Valor original antes de agregar (País: Barbados, Año: 2012): 89.24
# Valor original antes de agregar (País: Barbados, Año: 2013): 85.08
# Valor original antes de agregar (País: Barbados, Año: 2014): 80.91
# Valor original antes de agregar (País: Barbados, Año: 2015): 76.74
# Valor original antes de agregar (País: Barbados, Año: 2016): 72.57
# Valor original antes de agregar (País: Barbados, Año: 2017): 68.4
# Valor original antes de agregar (País: Barbados, Año: 2018): 68.4
# Valor original antes de agregar (País: Barbados, Año: 2019): 2097.16
# Valor original antes de agregar (País: Barbados, Año: 2020): 2097.16
# Valor original antes de agregar (País: Barbados, Año: 2021): 2097.16
# Valor original antes de agregar (País: Barbados, Año: 2022): 2097.16
# Valor original antes de agregar (País: Belarus, Año: 1990): 2097.16
# Valor original antes de agregar (País: Belarus, Año: 1991): 2097.16
# Valor original antes de agregar (País: Belarus, Año: 1992): 1881.7
# Valor original antes de agregar (País: Belarus, Año: 1993): 1822.95
# Valor original antes de agregar (País: Belarus, Año: 1994): 1817.1
# Valor original antes de agregar (País: Belarus, Año: 1995): 1962.61
# Valor original antes de agregar (País: Belarus, Año: 1996): 1603.58
# Valor original antes de agregar (País: Belarus, Año: 1997): 1919.86
# Valor original antes de agregar (País: Belarus, Año: 1998): 2347.57
# Valor original antes de agregar (País: Belarus, Año: 1999): 3646.91
# Valor original antes de agregar (País: Belarus, Año: 2000): 3890.56
# Valor original antes de agregar (País: Belarus, Año: 2001): 4235.1
# Valor original antes de agregar (País: Belarus, Año: 2002): 3880.08
# Valor original antes de agregar (País: Belarus, Año: 2003): 3874.87
# Valor original antes de agregar (País: Belarus, Año: 2004): 3386.54
# Valor original antes de agregar (País: Belarus, Año: 2005): 3078.92
# Valor original antes de agregar (País: Belarus, Año: 2006): 2422.74
# Valor original antes de agregar (País: Belarus, Año: 2007): 2229.08
# Valor original antes de agregar (País: Belarus, Año: 2008): 1892.13
# Valor original antes de agregar (País: Belarus, Año: 2009): 1463.89
# Valor original antes de agregar (País: Belarus, Año: 2010): 1077.76
# Valor original antes de agregar (País: Belarus, Año: 2011): 721.32
# Valor original antes de agregar (País: Belarus, Año: 2012): 839.88
# Valor original antes de agregar (País: Belarus, Año: 2013): 4171.29
# Valor original antes de agregar (País: Belarus, Año: 2014): 4589.42
# Valor original antes de agregar (País: Belarus, Año: 2015): 4117.78
# Valor original antes de agregar (País: Belarus, Año: 2016): 4230.9
# Valor original antes de agregar (País: Belarus, Año: 2017): 9560.49
# Valor original antes de agregar (País: Belarus, Año: 2018): 8529.07
# Valor original antes de agregar (País: Belarus, Año: 2019): 9204
# Valor original antes de agregar (País: Belarus, Año: 2020): 8822
# Valor original antes de agregar (País: Belarus, Año: 2021): 9186
# Valor original antes de agregar (País: Belarus, Año: 2022): 9776
# Valor original antes de agregar (País: Belgium, Año: 1990): 8244.02
# Valor original antes de agregar (País: Belgium, Año: 1991): 6712.05
# Valor original antes de agregar (País: Belgium, Año: 1992): 6516.47
# Valor original antes de agregar (País: Belgium, Año: 1993): 5496.04
# Valor original antes de agregar (País: Belgium, Año: 1994): 4644.53
# Valor original antes de agregar (País: Belgium, Año: 1995): 6297.22
# Valor original antes de agregar (País: Belgium, Año: 1996): 6584.48
# Valor original antes de agregar (País: Belgium, Año: 1997): 6334.74
# Valor original antes de agregar (País: Belgium, Año: 1998): 7179.63
# Valor original antes de agregar (País: Belgium, Año: 1999): 6479.24
# Valor original antes de agregar (País: Belgium, Año: 2000): 6570.44
# Valor original antes de agregar (País: Belgium, Año: 2001): 6245.92
# Valor original antes de agregar (País: Belgium, Año: 2002): 6355.29
# Valor original antes de agregar (País: Belgium, Año: 2003): 5940.6
# Valor original antes de agregar (País: Belgium, Año: 2004): 5667.46
# Valor original antes de agregar (País: Belgium, Año: 2005): 5575.94
# Valor original antes de agregar (País: Belgium, Año: 2006): 5065.85
# Valor original antes de agregar (País: Belgium, Año: 2007): 9074.21
# Valor original antes de agregar (País: Belgium, Año: 2008): 9074.21
# Valor original antes de agregar (País: Belgium, Año: 2009): 9074.21
# Valor original antes de agregar (País: Belgium, Año: 2010): 9074.21
# Valor original antes de agregar (País: Belgium, Año: 2011): 8449.91
# Valor original antes de agregar (País: Belgium, Año: 2012): 9007.08
# Valor original antes de agregar (País: Belgium, Año: 2013): 8742.92
# Valor original antes de agregar (País: Belgium, Año: 2014): 8306.6
# Valor original antes de agregar (País: Belgium, Año: 2015): 9095.89
# Valor original antes de agregar (País: Belgium, Año: 2016): 8829.62
# Valor original antes de agregar (País: Belgium, Año: 2017): 771
# Valor original antes de agregar (País: Belgium, Año: 2018): 696
# Valor original antes de agregar (País: Belgium, Año: 2019): 997
# Valor original antes de agregar (País: Belgium, Año: 2020): 1057.83
# Valor original antes de agregar (País: Belgium, Año: 2021): 1118.67
# Valor original antes de agregar (País: Belgium, Año: 2022): 1179.5
# Valor original antes de agregar (País: Belgium-Luxembourg (FAO), Año: 1990): 1240.33
# Valor original antes de agregar (País: Belgium-Luxembourg (FAO), Año: 1991): 1301.17
# Valor original antes de agregar (País: Belgium-Luxembourg (FAO), Año: 1992): 1362
# ...
# Valor original antes de agregar (País: Ukraine, Año: 1996): 13353.75
# Valor original antes de agregar (País: Ukraine, Año: 1997): 17339.14
# Valor original antes de agregar (País: Ukraine, Año: 1998): 20097.02
# Valor original antes de agregar (País: Ukraine, Año: 1999): 19630.81
# Valor original antes de agregar (País: Ukraine, Año: 2000): 15857.91
# Valor original antes de agregar (País: Ukraine, Año: 2001): 17779.43
# Valor original antes de agregar (País: Ukraine, Año: 2002): 24241.99
# Valor original antes de agregar (País: Ukraine, Año: 2003): 34027.65
# Valor original antes de agregar (País: Ukraine, Año: 2004): 39408.37
# Valor original antes de agregar (País: Ukraine, Año: 2005): 43750.43
# Valor original antes de agregar (País: Ukraine, Año: 2006): 51707.33
# Valor original antes de agregar (País: Ukraine, Año: 2007): 48711.53
# Valor original antes de agregar (País: Ukraine, Año: 2008): 47757.16
# Valor original antes de agregar (País: Ukraine, Año: 2009): 44416.24
# Valor original antes de agregar (País: Ukraine, Año: 2010): 55434.76
# Valor original antes de agregar (País: Ukraine, Año: 2011): 68346.57
# Valor original antes de agregar (País: Ukraine, Año: 2012): 76495.32
# Valor original antes de agregar (País: Ukraine, Año: 2013): 79906.65
# Valor original antes de agregar (País: Ukraine, Año: 2014): 79742.1
# Valor original antes de agregar (País: Ukraine, Año: 2015): 79676.06
# Valor original antes de agregar (País: Ukraine, Año: 2016): 40947.88
# Valor original antes de agregar (País: Ukraine, Año: 2017): 35773.06
# Valor original antes de agregar (País: Ukraine, Año: 2018): 42396.68
# Valor original antes de agregar (País: Ukraine, Año: 2019): 43668.61
# Valor original antes de agregar (País: Ukraine, Año: 2020): 40597.82
# Valor original antes de agregar (País: Ukraine, Año: 2021): 43544.19
# Valor original antes de agregar (País: Ukraine, Año: 2022): 46868.67
# Valor original antes de agregar (País: United Kingdom, Año: 1990): 53704.19
# Valor original antes de agregar (País: United Kingdom, Año: 1991): 49306.74
# Valor original antes de agregar (País: United Kingdom, Año: 1992): 51598.73
# Valor original antes de agregar (País: United Kingdom, Año: 1993): 51271.71
# Valor original antes de agregar (País: United Kingdom, Año: 1994): 45270.47
# Valor original antes de agregar (País: United Kingdom, Año: 1995): 49202.32
# Valor original antes de agregar (País: United Kingdom, Año: 1996): 55133.11
# Valor original antes de agregar (País: United Kingdom, Año: 1997): 51378.36
# Valor original antes de agregar (País: United Kingdom, Año: 1998): 64845.53
# Valor original antes de agregar (País: United Kingdom, Año: 1999): 52438.89
# Valor original antes de agregar (País: United Kingdom, Año: 2000): 74133.61
# Valor original antes de agregar (País: United Kingdom, Año: 2001): 63653.88
# Valor original antes de agregar (País: United Kingdom, Año: 2002): 64275.4
# Valor original antes de agregar (País: United Kingdom, Año: 2003): 66272.12
# Valor original antes de agregar (País: United Kingdom, Año: 2004): 67869.8
# Valor original antes de agregar (País: United Kingdom, Año: 2005): 69922.65
# Valor original antes de agregar (País: United Kingdom, Año: 2006): 67624.95
# Valor original antes de agregar (País: United Kingdom, Año: 2007): 68882.92
# Valor original antes de agregar (País: United Kingdom, Año: 2008): 66479.93
# Valor original antes de agregar (País: United Kingdom, Año: 2009): 77512.66
# Valor original antes de agregar (País: United Kingdom, Año: 2010): 83144.1
# Valor original antes de agregar (País: United Kingdom, Año: 2011): 90763.65
# Valor original antes de agregar (País: United Kingdom, Año: 2012): 83488.46
# Valor original antes de agregar (País: United Kingdom, Año: 2013): 83067.07
# Valor original antes de agregar (País: United Kingdom, Año: 2014): 82329.47
# Valor original antes de agregar (País: United Kingdom, Año: 2015): 82830.91
# Valor original antes de agregar (País: United Kingdom, Año: 2016): 154321.2
# Valor original antes de agregar (País: United Kingdom, Año: 2017): 160395.11
# Valor original antes de agregar (País: United Kingdom, Año: 2018): 138810.9
# Valor original antes de agregar (País: United Kingdom, Año: 2019): 142620.7
# Valor original antes de agregar (País: United Kingdom, Año: 2020): 138482.4
# Valor original antes de agregar (País: United Kingdom, Año: 2021): 138549.38
# Valor original antes de agregar (País: United Kingdom, Año: 2022): 152550.22
# Valor original antes de agregar (País: United States, Año: 1990): 162658.5
# Valor original antes de agregar (País: United States, Año: 1991): 165708.8
# Valor original antes de agregar (País: United States, Año: 1992): 168170.81
# Valor original antes de agregar (País: United States, Año: 1993): 159388.84
# Valor original antes de agregar (País: United States, Año: 1994): 155919.64
# Valor original antes de agregar (País: United States, Año: 1995): 140544.2
# Valor original antes de agregar (País: United States, Año: 1996): 133458.16
# Valor original antes de agregar (País: United States, Año: 1997): 135717.42
# Valor original antes de agregar (País: United States, Año: 1998): 140077.67
# Valor original antes de agregar (País: United States, Año: 1999): 133786.52
# Valor original antes de agregar (País: United States, Año: 2000): 142560.98
# Valor original antes de agregar (País: United States, Año: 2001): 145921.88
# Valor original antes de agregar (País: United States, Año: 2002): 124228.74
# Valor original antes de agregar (País: United States, Año: 2003): 122961.11
# Valor original antes de agregar (País: United States, Año: 2004): 130324.69
# Valor original antes de agregar (País: United States, Año: 2005): 135395.12
# Valor original antes de agregar (País: United States, Año: 2006): 132835.61
# Valor original antes de agregar (País: United States, Año: 2007): 144499.92
# Valor original antes de agregar (País: United States, Año: 2008): 137040.22
# Valor original antes de agregar (País: United States, Año: 2009): 142961.98
# Valor original antes de agregar (País: United States, Año: 2010): 142334.17
# Valor original antes de agregar (País: United States, Año: 2011): 152103.94
# Valor original antes de agregar (País: United States, Año: 2012): 121633.72
# Valor original antes de agregar (País: United States, Año: 2013): 135887.84
# Valor original antes de agregar (País: United States, Año: 2014): 141465.55
# Valor original antes de agregar (País: United States, Año: 2015): 138198.97
# Valor original antes de agregar (País: United States, Año: 2016): 1806217.8
# Valor original antes de agregar (País: United States, Año: 2017): 1793165.8
# Valor original antes de agregar (País: United States, Año: 2018): 1820024.1
# Valor original antes de agregar (País: United States, Año: 2019): 1835658.2
# Valor original antes de agregar (País: United States, Año: 2020): 1893203.2
# Valor original antes de agregar (País: United States, Año: 2021): 1958058
# Valor original antes de agregar (País: United States, Año: 2022): 2024780.9
# Valor original antes de agregar (País: Uruguay, Año: 1990): 2093054.8
# Valor original antes de agregar (País: Uruguay, Año: 1991): 2126357.8
# Valor original antes de agregar (País: Uruguay, Año: 1992): 2164650.5
# Valor original antes de agregar (País: Uruguay, Año: 1993): 2175291.8
# Valor original antes de agregar (País: Uruguay, Año: 1994): 2179938.5
# Valor original antes de agregar (País: Uruguay, Año: 1995): 2205096.5
# Valor original antes de agregar (País: Uruguay, Año: 1996): 2311194.8
# Valor original antes de agregar (País: Uruguay, Año: 1997): 2449878
# Valor original antes de agregar (País: Uruguay, Año: 1998): 2534535.2
# Valor original antes de agregar (País: Uruguay, Año: 1999): 2512975.8
# Valor original antes de agregar (País: Uruguay, Año: 2000): 2771371.8
# Valor original antes de agregar (País: Uruguay, Año: 2001): 2827763.5
# Valor original antes de agregar (País: Uruguay, Año: 2002): 2729787.2
# Valor original antes de agregar (País: Uruguay, Año: 2003): 3033142.5
# Valor original antes de agregar (País: Uruguay, Año: 2004): 3049581.5
# Valor original antes de agregar (País: Uruguay, Año: 2005): 3204611.5
# Valor original antes de agregar (País: Uruguay, Año: 2006): 3268107.2
# Valor original antes de agregar (País: Uruguay, Año: 2007): 3276473.5
# Valor original antes de agregar (País: Uruguay, Año: 2008): 3317168.5
# Valor original antes de agregar (País: Uruguay, Año: 2009): 3441204.2
# Valor original antes de agregar (País: Uruguay, Año: 2010): 3356044
# Valor original antes de agregar (País: Uruguay, Año: 2011): 3399053
# Valor original antes de agregar (País: Uruguay, Año: 2012): 3481209.5
# Valor original antes de agregar (País: Uruguay, Año: 2013): 3447761
# Valor original antes de agregar (País: Uruguay, Año: 2014): 3566063.8
# Valor original antes de agregar (País: Uruguay, Año: 2015): 3690934.8
# Valor original antes de agregar (País: Uruguay, Año: 2016): 98.34
# Valor original antes de agregar (País: Uruguay, Año: 2017): 186.98
# Valor original antes de agregar (País: Uruguay, Año: 2018): 364.25
# Valor original antes de agregar (País: Uruguay, Año: 2019): 441.05
# Valor original antes de agregar (País: Uruguay, Año: 2020): 573.51
# Valor original antes de agregar (País: Uruguay, Año: 2021): 586.83
# Valor original antes de agregar (País: Uruguay, Año: 2022): 638.15
# Valor original antes de agregar (País: Vanuatu, Año: 1990): 655.74
# Valor original antes de agregar (País: Vanuatu, Año: 1991): 838.59
# Valor original antes de agregar (País: Vanuatu, Año: 1992): 931.81
# Valor original antes de agregar (País: Vanuatu, Año: 1993): 899.48
# Valor original antes de agregar (País: Vanuatu, Año: 1994): 781.34
# Valor original antes de agregar (País: Vanuatu, Año: 1995): 926.47
# Valor original antes de agregar (País: Vanuatu, Año: 1996): 1026.48
# Valor original antes de agregar (País: Vanuatu, Año: 1997): 1209.62
# Valor original antes de agregar (País: Vanuatu, Año: 1998): 1248.87
# Valor original antes de agregar (País: Vanuatu, Año: 1999): 1268.63
# Valor original antes de agregar (País: Vanuatu, Año: 2000): 977.34
# Valor original antes de agregar (País: Vanuatu, Año: 2001): 724.34
# Valor original antes de agregar (País: Vanuatu, Año: 2002): 597.11
# Valor original antes de agregar (País: Vanuatu, Año: 2003): 694.92
# Valor original antes de agregar (País: Vanuatu, Año: 2004): 819.34
# Valor original antes de agregar (País: Vanuatu, Año: 2005): 953.54
# Valor original antes de agregar (País: Vanuatu, Año: 2006): 1506.28
# Valor original antes de agregar (País: Vanuatu, Año: 2007): 1483.51
# Valor original antes de agregar (País: Vanuatu, Año: 2008): 1357.2
# Valor original antes de agregar (País: Vanuatu, Año: 2009): 718.78
# Valor original antes de agregar (País: Vanuatu, Año: 2010): 576.13
# Valor original antes de agregar (País: Vanuatu, Año: 2011): 837.9
# Valor original antes de agregar (País: Vanuatu, Año: 2012): 1147.21
# Valor original antes de agregar (País: Vanuatu, Año: 2013): 1504.08
# Valor original antes de agregar (País: Vanuatu, Año: 2014): 1504.08
# Valor original antes de agregar (País: Vanuatu, Año: 2015): 1504.08
# Valor original antes de agregar (País: Vanuatu, Año: 2016): 2575
# Valor original antes de agregar (País: Vanuatu, Año: 2017): 2857
# Valor original antes de agregar (País: Vanuatu, Año: 2018): 1080
# Valor original antes de agregar (País: Vanuatu, Año: 2019): 1080
# Valor original antes de agregar (País: Vanuatu, Año: 2020): 1080
# Valor original antes de agregar (País: Vanuatu, Año: 2021): 1080
# Valor original antes de agregar (País: Vanuatu, Año: 2022): 1080
# Valor original antes de agregar (País: Vatican, Año: 1990): 716
# Valor original antes de agregar (País: Vatican, Año: 1991): 1670
# Valor original antes de agregar (País: Vatican, Año: 1992): 1797.51
# Valor original antes de agregar (País: Vatican, Año: 1993): 1925.03
# Valor original antes de agregar (País: Vatican, Año: 1994): 2052.54
# Valor original antes de agregar (País: Vatican, Año: 1995): 2180.05
# Valor original antes de agregar (País: Vatican, Año: 1996): 2307.57
# Valor original antes de agregar (País: Vatican, Año: 1997): 2435.08
# Valor original antes de agregar (País: Vatican, Año: 1998): 2562.59
# Valor original antes de agregar (País: Vatican, Año: 1999): 2690.11
# Valor original antes de agregar (País: Vatican, Año: 2000): 2817.62
# Valor original antes de agregar (País: Vatican, Año: 2001): 2945.13
# Valor original antes de agregar (País: Vatican, Año: 2002): 3072.65
# Valor original antes de agregar (País: Vatican, Año: 2003): 3200.16
# Valor original antes de agregar (País: Vatican, Año: 2004): 3327.67
# Valor original antes de agregar (País: Vatican, Año: 2005): 3455.19
# Valor original antes de agregar (País: Vatican, Año: 2006): 3582.7
# Valor original antes de agregar (País: Vatican, Año: 2007): 3710.21
# Valor original antes de agregar (País: Vatican, Año: 2008): 3837.73
# Valor original antes de agregar (País: Vatican, Año: 2009): 3965.24
# Valor original antes de agregar (País: Vatican, Año: 2010): 4092.75
# Valor original antes de agregar (País: Vatican, Año: 2011): 4220.27
# Valor original antes de agregar (País: Vatican, Año: 2012): 4347.78
# Valor original antes de agregar (País: Vatican, Año: 2013): 4196.64
# Valor original antes de agregar (País: Vatican, Año: 2014): 4196.64
# Valor original antes de agregar (País: Vatican, Año: 2015): 4196.64
# Valor original antes de agregar (País: Vatican, Año: 2016): 4196.64
# Valor original antes de agregar (País: Vatican, Año: 2017): 4196.64
# Valor original antes de agregar (País: Vatican, Año: 2018): 5727
# Valor original antes de agregar (País: Vatican, Año: 2019): 6753
# Valor original antes de agregar (País: Vatican, Año: 2020): 3303
# Valor original antes de agregar (País: Vatican, Año: 2021): 1716
# Valor original antes de agregar (País: Vatican, Año: 2022): 1664
# Valor original antes de agregar (País: Venezuela, Año: 1990): 2599
# Valor original antes de agregar (País: Venezuela, Año: 1991): 2538
# Valor original antes de agregar (País: Venezuela, Año: 1992): 2762
# Valor original antes de agregar (País: Venezuela, Año: 1993): 2883
# Valor original antes de agregar (País: Venezuela, Año: 1994): 2918.18
# Valor original antes de agregar (País: Venezuela, Año: 1995): 2953.36
# Valor original antes de agregar (País: Venezuela, Año: 1996): 2988.54
# Valor original antes de agregar (País: Venezuela, Año: 1997): 3023.72
# Valor original antes de agregar (País: Venezuela, Año: 1998): 3058.9
# Valor original antes de agregar (País: Venezuela, Año: 1999): 3094.08
# Valor original antes de agregar (País: Venezuela, Año: 2000): 3129.27
# Valor original antes de agregar (País: Venezuela, Año: 2001): 3164.45
# Valor original antes de agregar (País: Venezuela, Año: 2002): 3199.63
# Valor original antes de agregar (País: Venezuela, Año: 2003): 3234.81
# Valor original antes de agregar (País: Venezuela, Año: 2004): 3269.99
# Valor original antes de agregar (País: Venezuela, Año: 2005): 3305.17
# Valor original antes de agregar (País: Venezuela, Año: 2006): 3340.35
# Valor original antes de agregar (País: Venezuela, Año: 2007): 3375.53
# Valor original antes de agregar (País: Venezuela, Año: 2008): 2550.07
# Valor original antes de agregar (País: Venezuela, Año: 2009): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2010): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2011): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2012): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2013): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2014): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2015): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2016): 2185.07
# Valor original antes de agregar (País: Venezuela, Año: 2017): 2185.07
#        Año          País  Pepticidas
# 0     1990  Africa (FAO)    73504.69
# 1     1991  Africa (FAO)    69490.83
# 2     1992  Africa (FAO)    59769.13
# 3     1993  Africa (FAO)    53768.65
# 4     1994  Africa (FAO)    58312.42
# ...    ...           ...         ...
# 8245  2018      Zimbabwe         NaN
# 8246  2019      Zimbabwe         NaN
# 8247  2020      Zimbabwe         NaN
# 8248  2021      Zimbabwe         NaN
# 8249  2022      Zimbabwe         NaN
#
# [8250 rows x 3 columns]

# %%
import pandas as pd

def crear_dataframe(valores, años, paises, nombre_columna):    
    # Crear la lista para almacenar las filas de datos
    datos_lista = []
    
    # Variable para iterar sobre los valores
    indice_valor = 0
    
    # Iterar sobre los países y años
    for id_pais, nombre_pais in paises.items():  # Iterar sobre los países
        for año in años:  # Iterar sobre los años disponibles
            if indice_valor < len(valores):
                # Si hay un valor disponible, añadirlo a la fila
                fila = {
                    "Año": año,
                    "País": nombre_pais,
                    nombre_columna: valores[indice_valor]
                }
                indice_valor += 1
            else:
                # Si no hay más valores, completar con None (esto representará un NaN)
                fila = {
                    "Año": año,
                    "País": nombre_pais,
                    nombre_columna: None
                }
            datos_lista.append(fila)  # Añadir la fila a la lista
    
    # Convertir la lista a un DataFrame
    df = pd.DataFrame(datos_lista)
    
    # Eliminar las filas que tienen valores NaN en la columna correspondiente
    df = df.dropna(subset=[nombre_columna])
    
    # Redondear los valores y convertir a enteros
    df[nombre_columna] = df[nombre_columna].round().astype(int)
    
    # Formatear la columna con punto como separador de miles
    df[nombre_columna] = df[nombre_columna].apply(lambda x: f"{x:,}".replace(',', '.'))
    
    return df

# %% [markdown]
# ## Obtención de datos de la cantidad de precipitaciones (varibale independiente)

# %%
import pandas as pd
import requests

DATA_URL = "https://api.ourworldindata.org/v1/indicators/1005182.data.json"
METADATA_URL = "https://api.ourworldindata.org/v1/indicators/1005182.metadata.json"
datos, metadata = cargar_datos()  
valores, años, paises = procesar_datos(datos, metadata) 
df_precipitaciones = crear_dataframe(valores, años, paises,"Precipitaciones") 

# Mostrar los resultados en un display
display(df_precipitaciones)
# Out:
#         Año         País  Precipitaciones
# 0      1940  Afghanistan       217.678160
# 1      1941  Afghanistan      1388.520100
# 2      1942  Afghanistan        45.775917
# 3      1943  Afghanistan      2582.801800
# 4      1944  Afghanistan       899.675350
# ...     ...          ...              ...
# 16570  2020     Eswatini      1073.184600
# 16571  2021     Eswatini       147.840290
# 16572  2022     Eswatini       795.214360
# 16573  2023     Eswatini       421.734000
# 16574  2024     Eswatini       774.622860
#
# [16575 rows x 3 columns]

# %% [markdown]
# # ELIMINAR NULOS Y GUARDARLO EN .CSV

# %%
import pandas as pd

def limpiar_y_guardar_csv(df, nombre_archivo):
    # Eliminar filas con valores nulos
    df_limpio = df.dropna()

    # Guardar en un archivo CSV
    df_limpio.to_csv(nombre_archivo, index=False, encoding="utf-8")

    print(f"Datos guardados en '{nombre_archivo}' sin valores nulos.")
    
    return df_limpio

# %% [markdown]
# ## Parkinson

# %%
limpiar_y_guardar_csv(df_parkinson,"Datos_Parkinson.csv")
# Out:
# Datos guardados en 'Datos_Parkinson.csv' sin valores nulos.
#        Año           País   Parkinson
# 0     1990       Cambodia   21.533830
# 1     1991       Cambodia   21.483840
# 2     1992       Cambodia   21.502138
# 3     1993       Cambodia   21.607151
# 4     1994       Cambodia   21.767658
# ...    ...            ...         ...
# 7291  2017  South America  101.905710
# 7292  2018  South America  105.467110
# 7293  2019  South America  108.644905
# 7294  2020  South America  110.542580
# 7295  2021  South America  115.628784
#
# [7296 rows x 3 columns]

# %% [markdown]
# ## Contaminación de aire

# %%
limpiar_y_guardar_csv(df_aire,"Datos_contaminación_aire.csv")
# Out:
# Datos guardados en 'Datos_contaminación_aire.csv' sin valores nulos.
#        Año         País  Contaminacion_aire
# 0     1990  Afghanistan            9.830483
# 1     1991  Afghanistan            9.412167
# 2     1992  Afghanistan            8.970597
# 3     1993  Afghanistan            8.853374
# 4     1994  Afghanistan            9.138245
# ...    ...          ...                 ...
# 7099  2017     Zimbabwe            2.167512
# 7100  2018     Zimbabwe            2.128228
# 7101  2019     Zimbabwe            2.164050
# 7102  2020     Zimbabwe            2.195074
# 7103  2021     Zimbabwe            2.110314
#
# [7104 rows x 3 columns]

# %% [markdown]
# ## Muertes atribuidas a fuentes de agua inseguras

# %%
limpiar_y_guardar_csv(df_agua,"Datos_muertes_agua.csv")
# Out:
# Datos guardados en 'Datos_muertes_agua.csv' sin valores nulos.
#        Año         País  Muertes_agua
# 0     1990  Afghanistan     5876.4130
# 1     1991  Afghanistan     6145.5880
# 2     1992  Afghanistan     6818.0254
# 3     1993  Afghanistan     8395.5060
# 4     1994  Afghanistan     8754.6260
# ...    ...          ...           ...
# 7291  2017     Zimbabwe     3928.3027
# 7292  2018     Zimbabwe     3940.3884
# 7293  2019     Zimbabwe     3856.9373
# 7294  2020     Zimbabwe     3784.6410
# 7295  2021     Zimbabwe     3834.5771
#
# [7296 rows x 3 columns]

# %% [markdown]
# ## Exposicion al plomo

# %%
limpiar_y_guardar_csv(df_plomo,"Datos_exp_plomo.csv")
# Out:
# Datos guardados en 'Datos_exp_plomo.csv' sin valores nulos.
#        Año         País   Exp_plomo
# 0     1990  Afghanistan  2765.59400
# 1     1991  Afghanistan  2773.61840
# 2     1992  Afghanistan  2782.52610
# 3     1993  Afghanistan  2818.00600
# 4     1994  Afghanistan  2869.15920
# ...    ...          ...         ...
# 7099  2017     Zimbabwe   759.63760
# 7100  2018     Zimbabwe   755.67847
# 7101  2019     Zimbabwe   749.21820
# 7102  2020     Zimbabwe   739.96454
# 7103  2021     Zimbabwe   709.65390
#
# [7104 rows x 3 columns]

# %% [markdown]
# ## Uso de pepticidas

# %%
limpiar_y_guardar_csv(df_pepticidas,"Datos_uso_pepticidas.csv")
# Out:
# Datos guardados en 'Datos_uso_pepticidas.csv' sin valores nulos.
#        Año          País  Pepticidas
# 0     1990  Africa (FAO)    73504.69
# 1     1991  Africa (FAO)    69490.83
# 2     1992  Africa (FAO)    59769.13
# 3     1993  Africa (FAO)    53768.65
# 4     1994  Africa (FAO)    58312.42
# ...    ...           ...         ...
# 7910  2013     Venezuela     2185.07
# 7911  2014     Venezuela     2185.07
# 7912  2015     Venezuela     2185.07
# 7913  2016     Venezuela     2185.07
# 7914  2017     Venezuela     2185.07
#
# [7915 rows x 3 columns]

# %% [markdown]
# ## Precipitaciones

# %%
limpiar_y_guardar_csv(df_precipitaciones,"Datos_precipitaciones.csv")
# Out:
# Datos guardados en 'Datos_precipitaciones.csv' sin valores nulos.
#         Año         País  Precipitaciones
# 0      1940  Afghanistan       217.678160
# 1      1941  Afghanistan      1388.520100
# 2      1942  Afghanistan        45.775917
# 3      1943  Afghanistan      2582.801800
# 4      1944  Afghanistan       899.675350
# ...     ...          ...              ...
# 16570  2020     Eswatini      1073.184600
# 16571  2021     Eswatini       147.840290
# 16572  2022     Eswatini       795.214360
# 16573  2023     Eswatini       421.734000
# 16574  2024     Eswatini       774.622860
#
# [16575 rows x 3 columns]
